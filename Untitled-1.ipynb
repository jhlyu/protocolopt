# %%
import torch
import gc
import os
import json
import numpy as np
import bit_flip
import yaml
import math



with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

simulation_params = config["simulation_params"]
protocol_params = config["protocol_params"]
training_params = config["training_params"]

simulation_params['noise_sigma'] = math.sqrt(2 * simulation_params['gamma'] / simulation_params['beta'])  # od Einstein relation
centers = math.sqrt(protocol_params['b_endpoints'][0]/(2*protocol_params['a_endpoints'][0]))
#local_var = 1/(4 * protocol_params['b_endpoints'][0] * simulation_params['beta'])


torch_device = torch.device('cuda' if torch.cuda.is_available() else 'mps')
if os.path.exists('training_metrics.json'):
    with open( 'training_metrics.json', 'r') as f:
        metrics = json.load(f)
    mean_distance_list = metrics['mean_distance_list']
    #var_distance_list = metrics['var_distance_list']
    work_list = metrics['work_list']
    total_loss_list = metrics['total_loss_list']
    a_list_history = metrics['a_list_history']
    b_list_history = metrics['b_list_history']
    c_list_history = metrics['c_list_history']
    print("Loaded previous training metrics.")
else:
    mean_distance_list = []
    work_list = []
    total_loss_list = []
    a_list_history = []
    b_list_history = []
    c_list_history = []
    print("Initialized new training metrics.")
# Load or initialize alist and blist
if os.path.exists('work_checkpoint.pt'):
    checkpoint = torch.load('work_checkpoint.pt', weights_only=True)
    
    protocol_params['a_list'] = checkpoint['a_list'].to(torch_device).requires_grad_()
    protocol_params['b_list']= checkpoint['b_list'].to(torch_device).requires_grad_()
    protocol_params['c_list'] = checkpoint['c_list'].to(torch_device).requires_grad_()
    print("Loaded alist and blist from checkpoint.")

    optimizer_a = torch.optim.Adam([protocol_params['a_list']], lr=training_params['learning_rate'])
    optimizer_b = torch.optim.Adam([protocol_params['b_list']], lr= training_params['learning_rate'])
    optimizer_c = torch.optim.Adam([protocol_params['c_list']], lr= training_params['learning_rate'])
    optimizer_a.load_state_dict(checkpoint['optimizer_a_dict'])
    optimizer_b.load_state_dict(checkpoint['optimizer_b_dict'])
    optimizer_c.load_state_dict(checkpoint['optimizer_c_dict'])
    print("Loaded optimizer states.")
else:
    protocol_params['a_list'] = torch.zeros(protocol_params['num_coefficient'], device=torch_device, requires_grad=True)
    protocol_params['b_list'] = torch.zeros(protocol_params['num_coefficient'], device=torch_device, requires_grad=True)
    protocol_params['c_list'] = torch.zeros(protocol_params['num_coefficient'], device=torch_device, requires_grad=True)
    optimizer_a = torch.optim.Adam([protocol_params['a_list']], lr=training_params['learning_rate'])
    optimizer_b = torch.optim.Adam([protocol_params['b_list']], lr=training_params['learning_rate'])
    optimizer_c = torch.optim.Adam([protocol_params['c_list']], lr=training_params['learning_rate'])
    print("Initialized new alist, blist, and clist.")

for step in range(training_params['training_iterations']):
    optimizer_a.zero_grad()
    optimizer_b.zero_grad()
    optimizer_c.zero_grad()
    ######

    phase_data_generator = bit_flip.quartic_simulation(num_paths=training_params['batch_size'], params=simulation_params, a_list=protocol_params['a_list'], b_list=protocol_params['b_list'], a_endpoints=protocol_params['a_endpoints'], b_endpoints=protocol_params['b_endpoints'])
    phase_data, noise=phase_data_generator.trajectory_generator()

    tensor = bit_flip.bit_erasure(
        params=simulation_params, 
        phase_data=phase_data,
        a_list=protocol_params['a_list'], 
        b_list=protocol_params['b_list'],
        c_list=protocol_params['c_list'], 
        a_endpoints=protocol_params['a_endpoints'], 
        b_endpoints=protocol_params['b_endpoints'],
        c_endpoints=protocol_params['c_endpoints'])

    potential_advance = tensor.potential_value_advance_array()
    potential = tensor.potential_value_array()
    drift_a_grad = tensor.drift_grad_a_array()
    drift_b_grad = tensor.drift_grad_b_array()
    drift_c_grad = tensor.drift_grad_c_array()
    potential_a_grad = tensor.potential_grad_a_value_array()
    potential_b_grad = tensor.potential_grad_b_value_array()
    potential_c_grad = tensor.potential_grad_c_value_array()
    potential_a_advance_grad = tensor.potential_grad_a_value_advance_array()
    potential_b_advance_grad = tensor.potential_grad_b_value_advance_array()
    potential_c_advance_grad = tensor.potential_grad_c_value_advance_array()


 
    
    grad = bit_flip.grad_calc(
        sim_params=simulation_params,
        protocol_params=protocol_params['a_list'],
        noise_array=noise,
        potential_array=potential,
        potential_advance_array=potential_advance,
        potential_grad_array=potential_a_grad,
        potential_grad_advance_array=potential_a_advance_grad,
        drift_grad_array=drift_a_grad
    )
    work = grad.work_array().sum(axis=1).mean() 
    # Set current for gradient calculation
    x_last = phase_data[:,-1,0]
    
    # compute gradients for a protocol
    #work_grad_a = grad.work_grad()
    mean_grad_a = grad.current_grad(x_last)
    distance_grad_a = 2 * mean_grad_a * (x_last.mean()-centers)
    
    # switch to b protocol
    grad.protocol_params = protocol_params['b_list']
    grad.potential_grad_array = potential_b_grad
    grad.potential_grad_advance_array = potential_b_advance_grad
    grad.drift_grad_array = drift_b_grad

    # compute gradients for b protocol
    #work_grad_b = grad.work_grad()
    mean_grad_b = grad.current_grad(x_last)
    distance_grad_b = 2 * mean_grad_b * (x_last.mean()-centers)
  
    # switch to c protocol
    grad.protocol_params = protocol_params['c_list']
    grad.potential_grad_array = potential_c_grad
    grad.potential_grad_advance_array = potential_c_advance_grad
    grad.drift_grad_array = drift_c_grad

    # compute gradients for c protocol
    #work_grad_c = grad.work_grad()
    mean_grad_c = grad.current_grad(x_last)
    distance_grad_c = 2 * mean_grad_c * (x_last.mean()-centers)


    a_grad = training_params['alpha'] * (distance_grad_a) #+ training_params['alpha_2'] * (work_grad_a)
    b_grad = training_params['alpha'] * (distance_grad_b) #+ training_params['alpha_2'] * (work_grad_b)
    c_grad = training_params['alpha'] * (distance_grad_c) #+ training_params['alpha_2'] * (work_grad_c)

    protocol_params['a_list'].grad = a_grad
    protocol_params['b_list'].grad = b_grad
    protocol_params['c_list'].grad = c_grad

    x_loss = (x_last.mean())


    total_loss = training_params['alpha'] * x_loss + training_params['alpha_2'] * work
    mean_distance_list.append(x_loss.item())
    work_list.append(work.item())
    total_loss_list.append(total_loss.item())
    a_list_history.append(protocol_params['a_list'].detach().cpu().clone().tolist())
    b_list_history.append(protocol_params['b_list'].detach().cpu().clone().tolist())
    c_list_history.append(protocol_params['c_list'].detach().cpu().clone().tolist())

    optimizer_a.step()
    optimizer_b.step()
    optimizer_c.step()

    if step % 1 == 0:
        print(f"Step {step}: a = {protocol_params['a_list']}, b = {protocol_params['b_list']}, c = {protocol_params['c_list']}, x = {x_loss}, work = {work}, total loss = {total_loss}")


 # Save the lists after training using JSON

metrics = {
        'mean_distance_list': mean_distance_list,
        'work_list': work_list,
        'total_loss_list': total_loss_list,
        'a_list_history': a_list_history,
        'b_list_history': b_list_history,
        'c_list_history': c_list_history
    }
with open('training_metrics.json', 'w') as f:
    json.dump(metrics, f)


torch.save({
    'a_list': protocol_params['a_list'],
    'b_list': protocol_params['b_list'],
    'c_list': protocol_params['c_list'],
    'optimizer_b_dict': optimizer_b.state_dict(),
    'optimizer_a_dict': optimizer_a.state_dict(),
    'optimizer_c_dict': optimizer_c.state_dict(),
}, 'work_checkpoint.pt')
print("Checkpoint saved. Please restart kernel before next run.")
# Out:
# Initialized new training metrics.
# Initialized new alist, blist, and clist.
# Step 0: a = tensor([ 0.1000, -0.1000,  0.1000, -0.1000, -0.1000,  0.1000, -0.1000, -0.1000,
#         -0.1000,  0.1000, -0.1000, -0.1000, -0.1000,  0.1000,  0.1000, -0.1000,
#         -0.1000, -0.1000,  0.1000, -0.1000], device='mps:0',
#        requires_grad=True), b = tensor([-0.1000,  0.1000, -0.1000, -0.1000, -0.1000, -0.1000,  0.1000,  0.1000,
#          0.1000, -0.1000,  0.1000,  0.1000,  0.1000, -0.1000, -0.1000,  0.1000,
#          0.1000,  0.1000, -0.1000,  0.1000], device='mps:0',
#        requires_grad=True), c = tensor([-0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000,
#         -0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000, -0.1000,
#         -0.1000, -0.1000, -0.1000,  0.1000], device='mps:0',
#        requires_grad=True), x = -1.0224220752716064, work = 28.43985939025879, total loss = -1.0224220752716064
# Step 1: a = tensor([ 0.0708, -0.0964,  0.1784, -0.1805, -0.0775,  0.0791, -0.1982, -0.1803,
#         -0.1894,  0.0606, -0.1995, -0.1968, -0.0394,  0.1920,  0.1993, -0.0646,
#         -0.0731, -0.1996,  0.1838, -0.0397], device='mps:0',
#        requires_grad=True), b = tensor([-0.0825,  0.0987, -0.1800, -0.0310, -0.1855, -0.0584,  0.1901,  0.1940,
#          0.1981, -0.1527,  0.1874,  0.1967,  0.0485, -0.1974, -0.1886,  0.0494,
#          0.1046,  0.1998, -0.1701,  0.0603], device='mps:0',
#        requires_grad=True), c = tensor([-0.2001, -0.2001, -0.2001, -0.2001, -0.2001, -0.2001, -0.2000, -0.1996,
#         -0.1985, -0.2000, -0.2001, -0.1986, -0.1990, -0.1998, -0.1997, -0.1989,
#         -0.1992, -0.2000, -0.1996,  0.0898], device='mps:0',
#        requires_grad=True), x = -0.991890013217926, work = 44.20232391357422, total loss = -0.991890013217926
# Step 2: a = tensor([ 0.0282, -0.0636,  0.1892, -0.1892, -0.0128,  0.1118, -0.2970, -0.2694,
#         -0.2725,  0.0736, -0.2985, -0.2948, -0.0166,  0.2205,  0.2818, -0.0968,
#         -0.0855, -0.2993,  0.2080,  0.0343], device='mps:0',
#        requires_grad=True), b = tensor([-0.0401,  0.0705, -0.1901, -0.0668, -0.2648, -0.0881,  0.2846,  0.2798,
#          0.2948, -0.1831,  0.2760,  0.2941,  0.0131, -0.2492, -0.2381,  0.0742,
#          0.1142,  0.2956, -0.1620,  0.0098], device='mps:0',
#        requires_grad=True), c = tensor([-0.3002, -0.2993, -0.3000, -0.3004, -0.2996, -0.3002, -0.3000, -0.2992,
#         -0.2973, -0.2993, -0.3003, -0.2975, -0.2982, -0.2992, -0.2998, -0.2984,
#         -0.2978, -0.2983, -0.2886,  0.1037], device='mps:0',
#        requires_grad=True), x = -0.9477704763412476, work = 47.02350616455078, total loss = -0.9477704763412476
# Step 3: a = tensor([-0.0215, -0.0772,  0.1879, -0.2463, -0.0131,  0.1749, -0.3928, -0.3280,
#         -0.3234,  0.0961, -0.3974, -0.3751, -0.0132,  0.2028,  0.2581, -0.1263,
#         -0.1342, -0.2786,  0.1859,  0.0899], device='mps:0',
#        requires_grad=True), b = tensor([ 0.0064,  0.0836, -0.1911, -0.0183, -0.2649, -0.1504,  0.3813,  0.3483,
#          0.3621, -0.1735,  0.3689,  0.3767, -0.0127, -0.3147, -0.2337,  0.0809,
#          0.1458,  0.2887, -0.1077,  0.0053], device='mps:0',
#        requires_grad=True), c = tensor([-0.4006, -0.3990, -0.4002, -0.4009, -0.3995, -0.4007, -0.4003, -0.3994,
#         -0.3968, -0.3991, -0.3995, -0.3971, -0.3949, -0.3972, -0.3991, -0.3974,
#         -0.3966, -0.3945, -0.3804,  0.1157], device='mps:0',
#        requires_grad=True), x = -0.9608506560325623, work = 65.1182632446289, total loss = -0.9608506560325623
# Step 4: a = tensor([-0.0032, -0.0402,  0.2118, -0.2613,  0.0208,  0.2481, -0.4344, -0.3997,
#         -0.3508,  0.0641, -0.4913, -0.4202,  0.0117,  0.1607,  0.2523, -0.1577,
#         -0.1913, -0.2949,  0.1327,  0.1068], device='mps:0',
#        requires_grad=True), b = tensor([-0.0050,  0.0495, -0.2144, -0.0187, -0.2816, -0.2233,  0.4215,  0.4275,
#          0.4355, -0.1416,  0.4407,  0.4198, -0.0539, -0.3800, -0.2542,  0.0747,
#          0.1711,  0.3313, -0.0375,  0.0314], device='mps:0',
#        requires_grad=True), c = tensor([-0.5014, -0.4993, -0.5009, -0.5018, -0.4997, -0.5015, -0.5010, -0.5000,
#         -0.4951, -0.4991, -0.4992, -0.4966, -0.4925, -0.4950, -0.4984, -0.4965,
#         -0.4923, -0.4860, -0.4320,  0.1601], device='mps:0',
#        requires_grad=True), x = -1.015270709991455, work = 94.58537292480469, total loss = -1.015270709991455
# Step 5: a = tensor([-0.0063, -0.0249,  0.2497, -0.2224,  0.0487,  0.3083, -0.4515, -0.4135,
#         -0.3386,  0.0847, -0.5432, -0.4673,  0.0214,  0.1912,  0.2243, -0.1799,
#         -0.1738, -0.3243,  0.0642,  0.1497], device='mps:0',
#        requires_grad=True), b = tensor([ 0.0078,  0.0372, -0.2526, -0.0645, -0.2991, -0.2865,  0.4512,  0.4566,
#          0.4777, -0.1523,  0.4842,  0.4762, -0.0999, -0.4490, -0.2543,  0.0674,
#          0.1548,  0.3909,  0.0332,  0.0362], device='mps:0',
#        requires_grad=True), c = tensor([-0.6027, -0.6003, -0.6019, -0.6031, -0.6003, -0.6026, -0.6018, -0.6009,
#         -0.5940, -0.5987, -0.5989, -0.5971, -0.5914, -0.5940, -0.5943, -0.5924,
#         -0.5893, -0.5680, -0.4999,  0.1995], device='mps:0',
#        requires_grad=True), x = -1.01858651638031, work = 116.07926940917969, total loss = -1.01858651638031
# Step 6: a = tensor([-0.0237, -0.0113,  0.2687, -0.1971,  0.0781,  0.3790, -0.4666, -0.4518,
#         -0.3464,  0.1324, -0.5919, -0.4645,  0.0697,  0.2435,  0.2215, -0.2316,
#         -0.1537, -0.3213,  0.0329,  0.2109], device='mps:0',
#        requires_grad=True), b = tensor([ 0.0338,  0.0256, -0.2704, -0.0868, -0.3032, -0.3587,  0.4844,  0.5074,
#          0.5297, -0.1884,  0.5400,  0.4841, -0.1643, -0.5274, -0.2666,  0.0922,
#          0.1221,  0.3932,  0.0757,  0.0330], device='mps:0',
#        requires_grad=True), c = tensor([-0.7045, -0.7017, -0.7032, -0.7043, -0.7015, -0.7039, -0.7029, -0.7017,
#         -0.6934, -0.6987, -0.6988, -0.6981, -0.6905, -0.6924, -0.6914, -0.6900,
#         -0.6872, -0.6553, -0.5770,  0.2312], device='mps:0',
#        requires_grad=True), x = -0.9853097200393677, work = 123.77745819091797, total loss = -0.9853097200393677
# Step 7: a = tensor([-0.0649,  0.0150,  0.2732, -0.1740,  0.0978,  0.4333, -0.4999, -0.4958,
#         -0.3415,  0.1952, -0.6414, -0.4663,  0.1267,  0.2884,  0.2031, -0.2826,
#         -0.1492, -0.3451,  0.0335,  0.2506], device='mps:0',
#        requires_grad=True), b = tensor([ 0.0816, -0.0006, -0.2688, -0.1040, -0.3005, -0.4093,  0.5347,  0.5625,
#          0.5506, -0.2429,  0.6027,  0.5077, -0.2356, -0.6030, -0.2795,  0.1032,
#          0.0863,  0.4125,  0.0973,  0.0483], device='mps:0',
#        requires_grad=True), c = tensor([-0.8055, -0.8030, -0.8041, -0.8059, -0.8032, -0.8051, -0.8043, -0.8030,
#         -0.7939, -0.7988, -0.7989, -0.7994, -0.7904, -0.7918, -0.7894, -0.7884,
#         -0.7783, -0.7321, -0.6474,  0.2302], device='mps:0',
#        requires_grad=True), x = -0.9867555499076843, work = 111.64205932617188, total loss = -0.9867555499076843
# Step 8: a = tensor([-0.1081,  0.0602,  0.2869, -0.1478,  0.1128,  0.4868, -0.5301, -0.5171,
#         -0.3246,  0.2599, -0.6469, -0.4726,  0.1878,  0.3300,  0.1826, -0.3161,
#         -0.1200, -0.3271,  0.0337,  0.3024], device='mps:0',
#        requires_grad=True), b = tensor([ 0.1281, -0.0465, -0.2770, -0.1192, -0.2945, -0.4591,  0.5872,  0.5983,
#          0.5497, -0.2928,  0.6175,  0.5194, -0.3081, -0.6634, -0.2911,  0.0976,
#          0.0349,  0.4057,  0.1284,  0.0618], device='mps:0',
#        requires_grad=True), c = tensor([-0.9070, -0.9043, -0.9048, -0.9075, -0.9048, -0.9057, -0.9050, -0.9040,
#         -0.8948, -0.8994, -0.8994, -0.8993, -0.8903, -0.8914, -0.8880, -0.8885,
#         -0.8722, -0.8151, -0.7120,  0.2346], device='mps:0',
#        requires_grad=True), x = -0.9897876977920532, work = 97.12124633789062, total loss = -0.9897876977920532
# Step 9: a = tensor([-0.1663,  0.0665,  0.2786, -0.1320,  0.1166,  0.5409, -0.5779, -0.5471,
#         -0.3056,  0.3300, -0.6548, -0.4949,  0.2327,  0.3626,  0.1517, -0.3369,
#         -0.1101, -0.3208,  0.0503,  0.3234], device='mps:0',
#        requires_grad=True), b = tensor([ 0.1889, -0.0495, -0.2626, -0.1186, -0.2804, -0.5100,  0.6520,  0.6419,
#          0.5459, -0.3495,  0.6295,  0.5462, -0.3567, -0.7106, -0.2956,  0.0824,
#         -0.0083,  0.4096,  0.1410,  0.0879], device='mps:0',
#        requires_grad=True), c = tensor([-1.0077, -1.0050, -1.0048, -1.0084, -1.0061, -1.0055, -1.0055, -1.0045,
#         -0.9945, -0.9994, -0.9985, -0.9994, -0.9904, -0.9916, -0.9868, -0.9878,
#         -0.9639, -0.9009, -0.7836,  0.2313], device='mps:0',
#        requires_grad=True), x = -0.8814570903778076, work = 84.69391632080078, total loss = -0.8814570903778076
# Step 10: a = tensor([-0.2265,  0.0645,  0.2621, -0.1225,  0.1282,  0.5854, -0.6327, -0.5619,
#         -0.2804,  0.4075, -0.6409, -0.5078,  0.2805,  0.3963,  0.1100, -0.3664,
#         -0.0983, -0.3276,  0.0680,  0.3279], device='mps:0',
#        requires_grad=True), b = tensor([ 0.2516, -0.0400, -0.2409, -0.1131, -0.2746, -0.5478,  0.7232,  0.6732,
#          0.5446, -0.4083,  0.6257,  0.5578, -0.4078, -0.7577, -0.3008,  0.0837,
#         -0.0487,  0.4293,  0.1464,  0.1106], device='mps:0',
#        requires_grad=True), c = tensor([-1.1076, -1.1054, -1.1050, -1.1096, -1.1071, -1.1044, -1.1059, -1.1039,
#         -1.0931, -1.0988, -1.0959, -1.0967, -1.0902, -1.0913, -1.0853, -1.0865,
#         -1.0552, -0.9863, -0.8555,  0.2212], device='mps:0',
#        requires_grad=True), x = -0.9287214875221252, work = 74.49380493164062, total loss = -0.9287214875221252
# Step 11: a = tensor([-0.2851,  0.0631,  0.2528, -0.1007,  0.1527,  0.6162, -0.6808, -0.5656,
#         -0.2457,  0.4916, -0.6269, -0.5257,  0.3156,  0.4205,  0.0579, -0.4051,
#         -0.0722, -0.3267,  0.1036,  0.3350], device='mps:0',
#        requires_grad=True), b = tensor([ 0.3129, -0.0319, -0.2249, -0.1226, -0.2806, -0.5615,  0.7958,  0.6991,
#          0.5360, -0.4780,  0.6308,  0.5726, -0.4473, -0.7927, -0.2892,  0.0964,
#         -0.0867,  0.4403,  0.1275,  0.1141], device='mps:0',
#        requires_grad=True), c = tensor([-1.2076, -1.2058, -1.2050, -1.2103, -1.2081, -1.2038, -1.2064, -1.2021,
#         -1.1910, -1.1992, -1.1939, -1.1953, -1.1896, -1.1907, -1.1831, -1.1848,
#         -1.1468, -1.0709, -0.9201,  0.2263], device='mps:0',
#        requires_grad=True), x = -0.9561164975166321, work = 74.68447875976562, total loss = -0.9561164975166321
# Step 12: a = tensor([-0.3470,  0.0506,  0.2252, -0.0955,  0.1600,  0.6358, -0.7186, -0.5557,
#         -0.2135,  0.5100, -0.6052, -0.5417,  0.3277,  0.4595,  0.0285, -0.4292,
#         -0.0566, -0.3387,  0.1197,  0.3309], device='mps:0',
#        requires_grad=True), b = tensor([ 0.3780, -0.0135, -0.1942, -0.1211, -0.2745, -0.5719,  0.8497,  0.7103,
#          0.5217, -0.4881,  0.6401,  0.5882, -0.4562, -0.8437, -0.3094,  0.0871,
#         -0.1124,  0.4591,  0.1148,  0.1178], device='mps:0',
#        requires_grad=True), c = tensor([-1.3077, -1.3066, -1.3054, -1.3115, -1.3095, -1.3028, -1.3061, -1.3003,
#         -1.2900, -1.2998, -1.2922, -1.2944, -1.2903, -1.2900, -1.2816, -1.2836,
#         -1.2388, -1.1555, -0.9694,  0.2390], device='mps:0',
#        requires_grad=True), x = -0.9981834292411804, work = 67.77339935302734, total loss = -0.9981834292411804
# Step 13: a = tensor([-0.4092,  0.0316,  0.2067, -0.0928,  0.1541,  0.6357, -0.7657, -0.5552,
#         -0.2041,  0.5301, -0.5766, -0.5490,  0.3485,  0.4914,  0.0031, -0.4660,
#         -0.0463, -0.3631,  0.1255,  0.3265], device='mps:0',
#        requires_grad=True), b = tensor([ 0.4426,  0.0075, -0.1720, -0.1151, -0.2490, -0.5651,  0.9084,  0.7253,
#          0.5146, -0.5040,  0.6406,  0.5967, -0.4771, -0.8855, -0.3290,  0.0870,
#         -0.1439,  0.4897,  0.1123,  0.1188], device='mps:0',
#        requires_grad=True), c = tensor([-1.4078, -1.4069, -1.4053, -1.4119, -1.4100, -1.4017, -1.4053, -1.3985,
#         -1.3885, -1.4004, -1.3907, -1.3926, -1.3902, -1.3882, -1.3778, -1.3803,
#         -1.3289, -1.2438, -1.0313,  0.2420], device='mps:0',
#        requires_grad=True), x = -0.9610201716423035, work = 60.91334533691406, total loss = -0.9610201716423035
# Step 14: a = tensor([-0.4585,  0.0176,  0.1747, -0.1045,  0.1382,  0.6269, -0.8107, -0.5542,
#         -0.2103,  0.5506, -0.5412, -0.5456,  0.3575,  0.5036, -0.0254, -0.5029,
#         -0.0688, -0.3881,  0.1252,  0.3259], device='mps:0',
#        requires_grad=True), b = tensor([ 0.4974,  0.0219, -0.1384, -0.0936, -0.2075, -0.5556,  0.9619,  0.7407,
#          0.5234, -0.5192,  0.6277,  0.5958, -0.4863, -0.9027, -0.3340,  0.0855,
#         -0.1395,  0.5242,  0.1134,  0.1228], device='mps:0',
#        requires_grad=True), c = tensor([-1.5074, -1.5068, -1.5051, -1.5114, -1.5098, -1.4997, -1.5032, -1.4970,
#         -1.4867, -1.4993, -1.4887, -1.4917, -1.4893, -1.4865, -1.4689, -1.4757,
#         -1.4196, -1.3325, -1.1036,  0.2232], device='mps:0',
#        requires_grad=True), x = -0.9300662875175476, work = 69.19654846191406, total loss = -0.9300662875175476
# Step 15: a = tensor([-0.5210, -0.0228,  0.1316, -0.1257,  0.1383,  0.6086, -0.8707, -0.5512,
#         -0.2465,  0.5603, -0.5210, -0.5542,  0.3674,  0.5209, -0.0328, -0.5430,
#         -0.0826, -0.4049,  0.1070,  0.3228], device='mps:0',
#        requires_grad=True), b = tensor([ 0.5648,  0.0634, -0.0924, -0.0623, -0.1868, -0.5338,  1.0283,  0.7514,
#          0.5566, -0.5193,  0.6339,  0.6095, -0.4942, -0.9302, -0.3620,  0.0848,
#         -0.1418,  0.5499,  0.1127,  0.1071], device='mps:0',
#        requires_grad=True), c = tensor([-1.6071, -1.6061, -1.6048, -1.6108, -1.6091, -1.5974, -1.6003, -1.5961,
#         -1.5851, -1.5984, -1.5866, -1.5896, -1.5862, -1.5824, -1.5609, -1.5735,
#         -1.5100, -1.4215, -1.1827,  0.2035], device='mps:0',
#        requires_grad=True), x = -0.9365365505218506, work = 78.21732330322266, total loss = -0.9365365505218506
# Step 16: a = tensor([-0.5883, -0.0625,  0.0836, -0.1579,  0.1604,  0.6019, -0.9266, -0.5461,
#         -0.2872,  0.5677, -0.5244, -0.5787,  0.3709,  0.5324, -0.0647, -0.5834,
#         -0.0816, -0.4185,  0.0925,  0.3093], device='mps:0',
#        requires_grad=True), b = tensor([ 0.6351,  0.1071, -0.0364, -0.0192, -0.1881, -0.5212,  1.0947,  0.7618,
#          0.6007, -0.5101,  0.6594,  0.6386, -0.5009, -0.9500, -0.3679,  0.0919,
#         -0.1494,  0.5819,  0.1188,  0.1206], device='mps:0',
#        requires_grad=True), c = tensor([-1.7073, -1.7053, -1.7043, -1.7102, -1.7089, -1.6956, -1.6977, -1.6956,
#         -1.6838, -1.6983, -1.6854, -1.6883, -1.6843, -1.6792, -1.6527, -1.6703,
#         -1.5966, -1.5068, -1.2494,  0.1922], device='mps:0',
#        requires_grad=True), x = -0.9353275895118713, work = 98.04459381103516, total loss = -0.9353275895118713
# Step 17: a = tensor([-0.6504, -0.0943,  0.0614, -0.1545,  0.1808,  0.5985, -0.9672, -0.5521,
#         -0.3367,  0.5685, -0.5121, -0.5899,  0.3571,  0.5607, -0.0650, -0.6116,
#         -0.0673, -0.4201,  0.0779,  0.2901], device='mps:0',
#        requires_grad=True), b = tensor([ 0.6933,  0.1422, -0.0028, -0.0145, -0.1980, -0.5128,  1.1429,  0.7814,
#          0.6562, -0.4889,  0.6814,  0.6615, -0.4853, -0.9872, -0.3934,  0.0924,
#         -0.1693,  0.5936,  0.1252,  0.1279], device='mps:0',
#        requires_grad=True), c = tensor([-1.8076, -1.8041, -1.8042, -1.8106, -1.8088, -1.7929, -1.7937, -1.7942,
#         -1.7823, -1.7981, -1.7850, -1.7868, -1.7845, -1.7782, -1.7456, -1.7664,
#         -1.6841, -1.5871, -1.3191,  0.1873], device='mps:0',
#        requires_grad=True), x = -1.0309356451034546, work = 116.99866485595703, total loss = -1.0309356451034546
# Step 18: a = tensor([-0.7138, -0.1105,  0.0468, -0.1541,  0.2222,  0.6030, -0.9904, -0.5296,
#         -0.3781,  0.5751, -0.4931, -0.6034,  0.3457,  0.5935, -0.0278, -0.6503,
#         -0.0403, -0.4070,  0.0484,  0.2690], device='mps:0',
#        requires_grad=True), b = tensor([ 0.7498,  0.1607,  0.0173, -0.0088, -0.2336, -0.5078,  1.1719,  0.7687,
#          0.6940, -0.4714,  0.6991,  0.6790, -0.4716, -1.0232, -0.4447,  0.0872,
#         -0.2025,  0.5807,  0.1571,  0.1604], device='mps:0',
#        requires_grad=True), c = tensor([-1.9096, -1.9043, -1.9051, -1.9126, -1.9101, -1.8916, -1.8906, -1.8937,
#         -1.8819, -1.8998, -1.8852, -1.8858, -1.8836, -1.8764, -1.8399, -1.8586,
#         -1.7728, -1.6750, -1.3932,  0.1922], device='mps:0',
#        requires_grad=True), x = -1.1060590744018555, work = 138.2261199951172, total loss = -1.1060590744018555
# Step 19: a = tensor([-0.7788, -0.1380,  0.0217, -0.1716,  0.2652,  0.6153, -1.0252, -0.5077,
#         -0.4008,  0.5838, -0.4901, -0.6303,  0.3236,  0.6280,  0.0240, -0.6815,
#         -0.0248, -0.4100,  0.0068,  0.2328], device='mps:0',
#        requires_grad=True), b = tensor([ 0.8112,  0.1932,  0.0463,  0.0148, -0.2717, -0.5177,  1.2076,  0.7570,
#          0.7034, -0.4577,  0.7160,  0.7034, -0.4441, -1.0579, -0.5018,  0.0787,
#         -0.2299,  0.5801,  0.2053,  0.2067], device='mps:0',
#        requires_grad=True), c = tensor([-2.0120, -2.0049, -2.0060, -2.0136, -2.0115, -1.9915, -1.9879, -1.9939,
#         -1.9829, -2.0018, -1.9845, -1.9839, -1.9818, -1.9734, -1.9355, -1.9486,
#         -1.8578, -1.7673, -1.4768,  0.1788], device='mps:0',
#        requires_grad=True), x = -0.9752267599105835, work = 132.10604858398438, total loss = -0.9752267599105835
# Step 20: a = tensor([-0.8307, -0.1697,  0.0190, -0.1892,  0.3129,  0.6309, -1.0554, -0.4918,
#         -0.4212,  0.5826, -0.4800, -0.6439,  0.3112,  0.6667,  0.0658, -0.7042,
#          0.0085, -0.3997, -0.0450,  0.1750], device='mps:0',
#        requires_grad=True), b = tensor([ 0.8631,  0.2316,  0.0573,  0.0361, -0.3078, -0.5283,  1.2431,  0.7531,
#          0.7172, -0.4371,  0.7097,  0.7080, -0.4312, -1.1008, -0.5480,  0.0738,
#         -0.2660,  0.5768,  0.2563,  0.2708], device='mps:0',
#        requires_grad=True), c = tensor([-2.1154, -2.1066, -2.1084, -2.1157, -2.1138, -2.0917, -2.0867, -2.0962,
#         -2.0845, -2.1031, -2.0837, -2.0818, -2.0810, -2.0714, -2.0326, -2.0403,
#         -1.9467, -1.8581, -1.5663,  0.1492], device='mps:0',
#        requires_grad=True), x = -1.012799620628357, work = 161.85867309570312, total loss = -1.012799620628357
# Step 21: a = tensor([-0.8647, -0.1985, -0.0052, -0.2195,  0.3455,  0.6263, -1.0682, -0.4584,
#         -0.4268,  0.5864, -0.4652, -0.6495,  0.2711,  0.7023,  0.0961, -0.7084,
#          0.0618, -0.3774, -0.0902,  0.1068], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9031,  0.2658,  0.0875,  0.0697, -0.3299, -0.5241,  1.2689,  0.7334,
#          0.7177, -0.4307,  0.7078,  0.7087, -0.4015, -1.1398, -0.5818,  0.0549,
#         -0.3238,  0.5560,  0.3119,  0.3371], device='mps:0',
#        requires_grad=True), c = tensor([-2.2189, -2.2083, -2.2106, -2.2177, -2.2156, -2.1916, -2.1863, -2.1986,
#         -2.1849, -2.2040, -2.1823, -2.1811, -2.1808, -2.1701, -2.1308, -2.1322,
#         -2.0353, -1.9482, -1.6579,  0.1233], device='mps:0',
#        requires_grad=True), x = -0.9512611627578735, work = 138.13571166992188, total loss = -0.9512611627578735
# Step 22: a = tensor([-0.8819, -0.2266, -0.0342, -0.2504,  0.3804,  0.6178, -1.0959, -0.4330,
#         -0.4493,  0.6020, -0.4466, -0.6509,  0.2428,  0.7283,  0.0849, -0.7266,
#          0.1080, -0.3592, -0.1320,  0.0592], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9202,  0.2956,  0.1228,  0.1057, -0.3457, -0.5108,  1.3096,  0.7257,
#          0.7401, -0.4307,  0.6954,  0.7046, -0.3843, -1.1610, -0.5849,  0.0392,
#         -0.3788,  0.5398,  0.3715,  0.3906], device='mps:0',
#        requires_grad=True), c = tensor([-2.3200, -2.3100, -2.3126, -2.3184, -2.3169, -2.2914, -2.2862, -2.3008,
#         -2.2856, -2.3042, -2.2817, -2.2812, -2.2805, -2.2689, -2.2317, -2.2260,
#         -2.1255, -2.0368, -1.7409,  0.1102], device='mps:0',
#        requires_grad=True), x = -0.9558554887771606, work = 123.25858306884766, total loss = -0.9558554887771606
# Step 23: a = tensor([-0.8896, -0.2634, -0.0529, -0.2683,  0.4051,  0.6282, -1.1130, -0.4075,
#         -0.4550,  0.6045, -0.4209, -0.6473,  0.1958,  0.7570,  0.0725, -0.7427,
#          0.1681, -0.3339, -0.1934,  0.0300], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9280,  0.3362,  0.1506,  0.1341, -0.3537, -0.5147,  1.3435,  0.7197,
#          0.7522, -0.4168,  0.6725,  0.6944, -0.3467, -1.1867, -0.5897,  0.0279,
#         -0.4481,  0.5245,  0.4444,  0.4149], device='mps:0',
#        requires_grad=True), c = tensor([-2.4222, -2.4113, -2.4141, -2.4172, -2.4171, -2.3922, -2.3854, -2.4012,
#         -2.3865, -2.4055, -2.3822, -2.3815, -2.3804, -2.3689, -2.3346, -2.3209,
#         -2.2211, -2.1265, -1.8247,  0.1003], device='mps:0',
#        requires_grad=True), x = -0.9870202541351318, work = 133.35447692871094, total loss = -0.9870202541351318
# Step 24: a = tensor([-0.9111, -0.2965, -0.0782, -0.2865,  0.4362,  0.6424, -1.1367, -0.3830,
#         -0.4837,  0.5890, -0.3914, -0.6561,  0.1430,  0.7997,  0.0844, -0.7548,
#          0.2155, -0.3123, -0.2547,  0.0043], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9468,  0.3754,  0.1828,  0.1626, -0.3655, -0.5172,  1.3778,  0.7197,
#          0.7890, -0.3858,  0.6511,  0.6985, -0.3049, -1.2238, -0.6129,  0.0109,
#         -0.5142,  0.5036,  0.5079,  0.4377], device='mps:0',
#        requires_grad=True), c = tensor([-2.5239, -2.5121, -2.5148, -2.5157, -2.5171, -2.4934, -2.4847, -2.5023,
#         -2.4868, -2.5064, -2.4819, -2.4796, -2.4799, -2.4699, -2.4367, -2.4159,
#         -2.3179, -2.2136, -1.8903,  0.1080], device='mps:0',
#        requires_grad=True), x = -0.9203085899353027, work = 137.20799255371094, total loss = -0.9203085899353027
# Step 25: a = tensor([-0.9356, -0.3424, -0.1106, -0.2989,  0.4729,  0.6497, -1.1537, -0.3502,
#         -0.5256,  0.5716, -0.3559, -0.6536,  0.0835,  0.8369,  0.1136, -0.7611,
#          0.2517, -0.2946, -0.2998, -0.0219], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9697,  0.4263,  0.2228,  0.1817, -0.3860, -0.5149,  1.4041,  0.7154,
#          0.8360, -0.3468,  0.6357,  0.6918, -0.2557, -1.2650, -0.6564, -0.0253,
#         -0.5733,  0.4903,  0.5607,  0.4655], device='mps:0',
#        requires_grad=True), c = tensor([-2.6258, -2.6138, -2.6155, -2.6147, -2.6171, -2.5941, -2.5840, -2.6019,
#         -2.5863, -2.6058, -2.5827, -2.5796, -2.5778, -2.5719, -2.5378, -2.5090,
#         -2.4093, -2.2951, -1.9644,  0.0905], device='mps:0',
#        requires_grad=True), x = -1.0292460918426514, work = 135.89056396484375, total loss = -1.0292460918426514
# Step 26: a = tensor([-0.9493, -0.3402, -0.1283, -0.3041,  0.5367,  0.6915, -1.1285, -0.3077,
#         -0.5576,  0.5623, -0.3250, -0.6638,  0.0401,  0.8927,  0.1558, -0.7433,
#          0.2921, -0.2916, -0.3435, -0.0282], device='mps:0',
#        requires_grad=True), b = tensor([ 0.9811,  0.4289,  0.2458,  0.1929, -0.4398, -0.5532,  1.3908,  0.6923,
#          0.8619, -0.3126,  0.6282,  0.6896, -0.2292, -1.3260, -0.7083, -0.0808,
#         -0.6372,  0.4794,  0.6126,  0.4699], device='mps:0',
#        requires_grad=True), c = tensor([-2.7282, -2.7168, -2.7179, -2.7150, -2.7178, -2.6957, -2.6838, -2.7027,
#         -2.6869, -2.7069, -2.6850, -2.6795, -2.6779, -2.6752, -2.6391, -2.6054,
#         -2.5048, -2.3817, -2.0487,  0.0470], device='mps:0',
#        requires_grad=True), x = -1.1591590642929077, work = 135.29685974121094, total loss = -1.1591590642929077
# Step 27: a = tensor([-0.9757, -0.3288, -0.1487, -0.3074,  0.6043,  0.7404, -1.1281, -0.2642,
#         -0.5605,  0.5698, -0.2734, -0.6606, -0.0125,  0.9323,  0.2096, -0.7242,
#          0.3348, -0.3038, -0.3946, -0.0477], device='mps:0',
#        requires_grad=True), b = tensor([ 1.0068,  0.4227,  0.2722,  0.2002, -0.5027, -0.5970,  1.3953,  0.6679,
#          0.8664, -0.2943,  0.6025,  0.6814, -0.1900, -1.3673, -0.7635, -0.1277,
#         -0.7055,  0.4829,  0.6690,  0.4881], device='mps:0',
#        requires_grad=True), c = tensor([-2.8291, -2.8191, -2.8205, -2.8160, -2.8181, -2.7979, -2.7832, -2.8029,
#         -2.7861, -2.8071, -2.7854, -2.7811, -2.7803, -2.7791, -2.7402, -2.7035,
#         -2.6015, -2.4737, -2.1323,  0.0109], device='mps:0',
#        requires_grad=True), x = -1.0371980667114258, work = 107.1279067993164, total loss = -1.0371980667114258
# Step 28: a = tensor([-0.9919, -0.3068, -0.1527, -0.3013,  0.6795,  0.7855, -1.1251, -0.2232,
#         -0.5658,  0.5916, -0.2070, -0.6431, -0.0561,  0.9656,  0.2706, -0.7299,
#          0.3642, -0.3199, -0.4415, -0.0641], device='mps:0',
#        requires_grad=True), b = tensor([ 1.0213,  0.4059,  0.2821,  0.1958, -0.5721, -0.6401,  1.3941,  0.6427,
#          0.8715, -0.2907,  0.5568,  0.6604, -0.1556, -1.4095, -0.8257, -0.1509,
#         -0.7602,  0.4892,  0.7193,  0.5027], device='mps:0',
#        requires_grad=True), c = tensor([-2.9296, -2.9202, -2.9219, -2.9170, -2.9183, -2.9002, -2.8819, -2.9034,
#         -2.8835, -2.9054, -2.8836, -2.8841, -2.8848, -2.8827, -2.8380, -2.7984,
#         -2.6980, -2.5680, -2.2169, -0.0261], device='mps:0',
#        requires_grad=True), x = -1.0447559356689453, work = 83.05530548095703, total loss = -1.0447559356689453
# Step 29: a = tensor([-1.0062, -0.2927, -0.1483, -0.2833,  0.7405,  0.8365, -1.1227, -0.1888,
#         -0.5589,  0.6182, -0.1267, -0.6153, -0.1037,  0.9925,  0.3218, -0.7305,
#          0.4024, -0.3226, -0.4892, -0.0863], device='mps:0',
#        requires_grad=True), b = tensor([ 1.0369,  0.3965,  0.2810,  0.1796, -0.6314, -0.6897,  1.3942,  0.6182,
#          0.8668, -0.2965,  0.4929,  0.6290, -0.1208, -1.4458, -0.8742, -0.1751,
#         -0.8241,  0.4843,  0.7766,  0.5250], device='mps:0',
#        requires_grad=True), c = tensor([-3.0289, -3.0205, -3.0228, -3.0168, -3.0186, -3.0022, -2.9792, -3.0032,
#         -2.9816, -3.0036, -2.9805, -2.9845, -2.9887, -2.9846, -2.9378, -2.8935,
#         -2.7955, -2.6643, -2.3024, -0.0651], device='mps:0',
#        requires_grad=True), x = -1.0434552431106567, work = 62.290748596191406, total loss = -1.0434552431106567
# Step 30: a = tensor([-1.0135, -0.2846, -0.1460, -0.2769,  0.7937,  0.8741, -1.1362, -0.1579,
#         -0.5459,  0.6332, -0.0723, -0.6033, -0.1531,  1.0050,  0.3701, -0.7272,
#          0.4469, -0.3303, -0.5351, -0.1056], device='mps:0',
#        requires_grad=True), b = tensor([ 1.0489,  0.3956,  0.2844,  0.1744, -0.6815, -0.7290,  1.4074,  0.5973,
#          0.8575, -0.2969,  0.4579,  0.6138, -0.0856, -1.4667, -0.9234, -0.1998,
#         -0.8918,  0.4885,  0.8342,  0.5458], device='mps:0',
#        requires_grad=True), c = tensor([-3.1257, -3.1193, -3.1220, -3.1149, -3.1179, -3.1032, -3.0753, -3.1019,
#         -3.0792, -3.1005, -3.0769, -3.0836, -3.0910, -3.0866, -3.0393, -2.9896,
#         -2.8939, -2.7573, -2.3864, -0.0977], device='mps:0',
#        requires_grad=True), x = -0.9576364755630493, work = 48.4908332824707, total loss = -0.9576364755630493
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 76
#      73 ######
#      75 phase_data_generator = bit_flip.quartic_simulation(num_paths=training_params['batch_size'], params=simulation_params, a_list=protocol_params['a_list'], b_list=protocol_params['b_list'], a_endpoints=protocol_params['a_endpoints'], b_endpoints=protocol_params['b_endpoints'])
# ---> 76 phase_data, noise=phase_data_generator.trajectory_generator()
#      78 tensor = bit_flip.bit_erasure(
#      79     params=simulation_params,
#      80     phase_data=phase_data,
#    (...)
#      85     b_endpoints=protocol_params['b_endpoints'],
#      86     c_endpoints=protocol_params['c_endpoints'])
#      88 potential_advance = tensor.potential_value_advance_array()
#
# File ~/Documents/protocolopt/bit_flip.py:1353, in quartic_simulation.trajectory_generator(self)
#    1351 noise_array = torch.randn(self.num_paths, num_steps, device=self.torch_device) * (noise_sigma * math.sqrt(self.params['dt']))
#    1352 phase_array = torch.zeros((self.num_paths, num_steps + 1, 2), device=self.torch_device) # 2 for position and velocity
# -> 1353 phase_array[:, 0, 0] = self.mh_sampler() # initial position
#    1354 phase_array[:, 0, 1] = self.velocity_sample_distribution() # initial velocity
#    1355 for i in range(num_steps):
#    1356     # Update position using the Euler-Maruyama method
#    1357     # dx = v * dt
#    1358     # dv = -gamma * v + ( 4*b*x - 4*a*x^3) * dt + noise
#
# File ~/Documents/protocolopt/bit_flip.py:1310, in quartic_simulation.mh_sampler(self)
#    1307     x_new = x + torch.randn(1, device='cpu') * self.local_std
#    1309 delta = self.log_prob(x_new) - self.log_prob(x)
# -> 1310 if torch.log(torch.rand(1, device='cpu')) < delta:
#    1311     x = x_new
#    1313 samples[i] = x  # store directly without .item()
#
# KeyboardInterrupt:

# %%
phase_data[:,-1,0].mean()
# Out:
# tensor(0.0424, device='mps:0', grad_fn=<MeanBackward0>)
